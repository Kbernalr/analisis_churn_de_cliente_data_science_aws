# %%
#Se cargan las funciones creadas para feactures
import sys
from pathlib import Path  # Manejo de rutas de archivo 
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")
pd.set_option("display.max_columns", None)

#Encontrar la raiz del proyecto
ROOT = Path.cwd()
while not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT)) # Encuentra la carpeta src
from src.function_clean import load_data, guardar_dataframe
from src.function_features import crear_features

# %%
#Ruta de la base de datos
ruta = "../database/silver/clean_data/clean_data_customers.csv"

# %%
df = load_data(ruta) # Cargando los datos
df.head(5) # revision de los 5 valores
# Out:
#   signup_date last_purchase_date  monthly_spend  total_shipments  churn_label  \
# 0  2023-01-15         2025-12-05          450.5             12.0          0.0
# 1  2023-02-20         2025-05-10         1200.0             45.0          0.0
# 2  2023-04-12         2025-06-01          890.2             22.0          0.0
# 3  2023-05-30         2024-12-20          310.0              5.0          1.0
# 4  2023-06-21         2025-04-15         2500.0              NaN          0.0
#
#   customer_id_anonymous
# 0                C00000
# 1                C00001
# 2                C00002
# 3                C00003
# 4                C00004

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   signup_date            109 non-null    str
#  1   last_purchase_date     106 non-null    str
#  2   monthly_spend          88 non-null     float64
#  3   total_shipments        107 non-null    float64
#  4   churn_label            109 non-null    float64
#  5   customer_id_anonymous  109 non-null    str
# dtypes: float64(3), str(3)
# memory usage: 5.2 KB

# %%
df_features = crear_features(df) #features

df_features.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id_anonymous     109 non-null    str
#  1   monthly_spend             88 non-null     float64
#  2   total_shipments           107 non-null    float64
#  3   antiguedad_dias           109 non-null    int64
#  4   dias_desde_ultima_compra  106 non-null    float64
#  5   monthly_spend_is_null     109 non-null    int64
#  6   churn_label               109 non-null    float64
# dtypes: float64(4), int64(2), str(1)
# memory usage: 6.1 KB

# %% [markdown]
# Con el fin de mejorar la capacidad predictiva del modelo y basado en el analisis eda, se realizo un proceso de Feature Engineering sobre las variables temporales. Estas nuevas caracteristicas permiten capturar informacion relacionada con la antiguedad del cliente, su nivel de actividad reciente y valores faltantes en la variable monthly_spend, factores que suelen estar asociados con la probabilidad de abandono.

# %%
#Ruta de la base de datos
ruta = "../database/silver/features_data/features_data_customers.csv"

# %%
guardar_dataframe(df_features,ruta)
# Out:
# Archivo guardado correctamente en: ..\database\silver\features_data\features_data_customers.csv
